# %%
# %run Diagram1.py
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File ~/Documents/GitHub/SE_Modelling-/Diagram1.py:57
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": 1,
#       6    "id": "afd9e4e5-6ac9-4c41-992d-38a8f4befca2",
#       7    "metadata": {},
#       8    "outputs": [
#       9     {
#      10      "ename": "ModuleNotFoundError",
#      11      "evalue": "No module named 'diagrams'",
#      12      "output_type": "error",
#      13      "traceback": [
#      14       "\u001b---------------------------------------------------------------------------\u001b",
#      15       "\u001bModuleNotFoundError\u001b                       Traceback (most recent call last)",
#      16       "Cell \u001bIn[1], line 1\u001b\n\u001b----> 1\u001b \u001bfrom\u001b \u001bdiagrams\u001b \u001bimport\u001b Diagram\n",
# ...
